# %%
from scrapy import Selector

# %%
article = {}

# %%
text = """
<div class="fs-dtrows clearfix">
            <div class="fs-dtcol1">
                <div class="fs-dtbox">
                                            <div class="fs-dttabsmain fs-dttabfix">
                            <div class="fs-dttabsmbox">
                                <ul class="fs-dttabs fs-dttabtop">
                                        <li class="active"><a toscroll="" href="#dac-diem-noi-bat" title="" onclick="ga('send', 'event', 'Product Detail', 'Click Content Detail Navigations', 'Đặc điểm nổi bật');">Đặc điểm nổi bật</a></li>
                                                                            <li style="display:none;"><a toscroll="" href="#thong-so-ky-thuat" title="" onclick="ga('send', 'event', 'Product Detail', 'Click Content Detail Navigations', 'Thông số kỹ thuật');">Thông số kỹ thuật</a></li>

                                    <li><a toscroll="" href="#danh-gia-nhan-xet" title="" onclick="ga('send', 'event', 'Product Detail', 'Click Content Detail Navigations', 'Đánh giá &amp; Nhận xét');">Đánh giá &amp; Nhận xét</a></li>
                                    <li><a toscroll="" href="#hoi-dap" title="" onclick="ga('send', 'event', 'Product Detail', 'Click Content Detail Navigations', 'Hỏi &amp; Đáp');">Hỏi &amp; Đáp</a></li>

                                        <li><a toscroll="" href="#hinh-anh" title="" onclick="ga('send', 'event', 'Product Detail', 'Click Content Detail Navigations', 'Hình Ảnh');">Hình Ảnh</a></li>
                                    <li class="fs-dttbhide mphu-kien" style="display: none;"><a toscroll="" href="#phu-kien" title="" onclick="ga('send', 'event', 'Product Detail', 'Click Content Detail Navigations', 'Phụ kiện');">Phụ kiện</a></li>

                                    <li class="fs-dttbhide mtin-tuc"><a toscroll="" href="#tin-tuc" title="" onclick="ga('send', 'event', 'Product Detail', 'Click Content Detail Navigations', 'Tin tức');">Tin tức</a></li>
                                </ul>
                                <a class="fs-mncalls clearfix" href="" title="">
                                    <i class="icdt fs-imncall"></i>
                                    <span>TƯ VẤN MIỄN PHÍ</span>
                                    <strong>1800 6601</strong>
                                </a>
                                    <a class="fs-dttbmua dts-addtocart" href="javascript:void(0)" title="">Mua ngay</a>
                            </div>
                        </div>
                                                <div class="fs-dtcontent" id="dac-diem-noi-bat">

                                <div class="fs-dtctboxslide clearfix">
                                    <div class="owl-carousel fsdtsld otherlazy owl-loaded owl-drag afterlazyma" data-items="1">
                                            
                                            
                                            
                                            
                                    <div class="owl-stage-outer"><div class="owl-stage" style="transform: translate3d(0px, 0px, 0px); transition: all 0s ease 0s; width: 2848px;"><div class="owl-item active" style="width: 712px;"><div class="item">
                                                <img class="owl-lazy" alt="Realme 5 3GB-64GB" src="https://images.fpt.shop/unsafe/fit-in/840x472/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/9/26/637051183310669324_realme-5-6.jpg" style="opacity: 1;">
                                            </div></div><div class="owl-item" style="width: 712px;"><div class="item">
                                                <img class="owl-lazy" alt="Realme 5 3GB-64GB" src="https://images.fpt.shop/unsafe/fit-in/840x472/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/9/26/637051183310679379_realme-5-1.jpg" style="opacity: 1;">
                                            </div></div><div class="owl-item" style="width: 712px;"><div class="item">
                                                <img class="owl-lazy" alt="Realme 5 3GB-64GB" src="https://images.fpt.shop/unsafe/fit-in/840x472/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/9/26/637051183311019364_realme-5-3.jpg" style="opacity: 1;">
                                            </div></div><div class="owl-item" style="width: 712px;"><div class="item">
                                                <img class="owl-lazy" alt="Realme 5 3GB-64GB" src="https://images.fpt.shop/unsafe/fit-in/840x472/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/9/26/637051183311419328_realme-5-7.jpg" style="opacity: 1;">
                                            </div></div></div></div><div class="owl-nav"><div class="owl-prev disabled"></div><div class="owl-next"></div></div><div class="owl-dots"><div class="owl-dot active"><span></span></div><div class="owl-dot"><span></span></div><div class="owl-dot"><span></span></div><div class="owl-dot"><span></span></div></div></div>
                                </div>
								<style>.fsdtcts{font-size:16px;line-height:1.5}.fsdtcts h1,.fsdtcts h2,.fsdtcts h3,.fsdtcts h4{font-size:20px;margin:10px 0}.fsdtcts a{color:#18487a}.fsdtcts p{margin:10px 0}.fsdtcts img{margin-bottom:10px}</style>
                                <div class="fs-dtctbox fsdtcts clearfix">
                                    <h3 class="dgctpro">Đánh giá chi tiết Realme 5 3GB-64GB</h3>
                                    <p style="text-align: justify;"><strong>Sở hữu 4 camera sau đẳng cấp, dung lượng pin 5000 mAh siêu khủng cùng màn hình lớn tuyệt mỹ, Realme 5 xứng đáng là người bạn đồng hành đáng tin cậy của bạn trong cuộc sống hiện đại.</strong></p>

<p style="text-align: center;"><strong><img alt="Realme 5" data-original="https://fptshop.com.vn/Uploads/images/2015/Tin-Tuc/QuanLNH2/realme-5-1.jpg" class="lazydetail" src="https://fptshop.com.vn/Uploads/images/2015/Tin-Tuc/QuanLNH2/realme-5-1.jpg" style="display: inline;"></strong></p>

<h3 style="text-align: justify;"><strong>Pin 5000 mAh, thoải mái sử dụng cả ngày</strong></h3>

<p style="text-align: justify;">Realme 5 mang trên mình viên pin dung lượng 5000 mAh, con số lớn bậc nhất thị trường hiện nay. Với dung lượng pin khó tin, Realme 5 cho thời gian sử dụng cực dài, lên tới 29.9 ngày ở chế độ chờ. Trong sử dụng thực tế, bạn có thể chơi game nặng liên tục 8,5 giờ; nghe nhạc trong 30,8 giờ; gọi điện trong 48,9 giờ và xem Youtube trong 19,1 giờ. Ở điều kiện sử dụng thông thường, Realme 5 cho phép bạn sử dụng thoải mái 2 ngày mới cần phải sạc, hết sức ấn tượng.</p>

<p style="text-align: center;"><img alt="pin Realme 5" data-original="https://fptshop.com.vn/Uploads/images/2015/Tin-Tuc/QuanLNH2/realme-5-2.jpg" class="lazydetail" src="..."></p>

<h3 style="text-align: justify;"><strong>Dẫn đầu xu hướng với 4 camera sau</strong></h3>

<p style="text-align: justify;">Hãy cùng xem bạn sẽ làm được những gì với 4 camera sau trên Realme 5. Camera chính 12MP khẩu độ lớn f/1.8 mang đến những bức ảnh chụp đêm sáng rõ, sắc nét; camera góc siêu rộng 8MP cho góc chụp rộng tới 119 độ và cuối cùng, việc sử dụng đến 2 camera hỗ trợ đo độ sâu sẽ giúp ảnh chụp xóa phông của Realme 5 chuyên nghiệp hơn bao giờ hết. Bạn có thể thử chế độ chụp xóa phông mới hiệu ứng phim trường hay chế độ chụp đêm siêu điểm ảnh 4-in-1 thông minh, Realme 5 sẽ làm bạn bất ngờ về những gì mà camera máy làm được.</p>

<p style="text-align: center;"><img alt="camera Realme 5" data-original="https://fptshop.com.vn/Uploads/images/2015/Tin-Tuc/QuanLNH2/realme-5-3.jpg" class="lazydetail" src="..."></p>

<h3 style="text-align: justify;"><strong>Snapdragon 665 AIE, bộ vi xử lý 11nm siêu mạnh</strong></h3>

<p style="text-align: justify;">Bộ não của Realme 5 là con chip Snapdragon 665. Đây là bộ vi xử lý siêu mạnh được sản xuất trên tiến trình 11nm tiên tiến, mạnh mẽ, ít tỏa nhiệt và tiết kiệm pin hơn. Với Snapdragon 665, bạn có thể xử lý trơn tru mọi tác vụ thông thường, chơi game mượt mà, kể cả những tựa game nặng đồ họa cao. Realme 5 có 64GB bộ nhớ trong, đảm bảo không gian lưu trữ rộng lớn cho tất cả nhu cầu của bạn.</p>

<p style="text-align: center;"><img alt="hiệu năng Realme 5" data-original="https://fptshop.com.vn/Uploads/images/2015/Tin-Tuc/QuanLNH2/realme-5-4.jpg" class="lazydetail" src="..."></p>

<h3 style="text-align: justify;"><strong>Màn hình tràn viền 6,5 inch mini-drop mới</strong></h3>

<p style="text-align: justify;">Màn hình Realme 5 có kích thước lớn 6,5 inch viền siêu mỏng và phần khuyết mini-drop nhỏ hơn so với thế hệ trước. Nhờ vậy bạn sẽ được tận hưởng màn hình chiếm tới 89% diện tích mặt trước, hiển thị tuyệt mỹ và mang đến những trải nghiệm sống động. Hãy tận hưởng bộ phim hay tựa game yêu thích, bạn sẽ cảm nhận được điều khác biệt.</p>

<p style="text-align: center;"><img alt="màn hình Realme 5" data-original="https://fptshop.com.vn/Uploads/images/2015/Tin-Tuc/QuanLNH2/realme-5-5.jpg" class="lazydetail" src="..."></p>

<h3 style="text-align: justify;"><strong>Thiết kế pha lê kim cương sang trọng</strong></h3>

<p style="text-align: justify;">Thiết kế Realme 5 lấy cảm hứng từ một viên kim cương cổ điển, lấp lánh phản chiếu ánh sáng với những khối màu riêng biệt. Để tạo nên mặt lưng có màu sắc ba chiều nano độc đáo, các kỹ sư của Realme đã phải đánh bóng tới 133 lần. Chiếc điện thoại trên tay bạn thực sự tỏa sáng, sang trọng ở mọi góc nhìn.</p>

<p style="text-align: center;"><img alt="thiết kế Realme 5" data-original="https://fptshop.com.vn/Uploads/images/2015/Tin-Tuc/QuanLNH2/realme-5-6.jpg" class="lazydetail" src="..."></p>

<h3 style="text-align: justify;"><strong>Bền vững hơn với khả năng chống nước</strong></h3>

<p style="text-align: justify;">Realme 5 có khả năng chống nước cơ bản, giúp bạn tránh được mọi nguy cơ thường ngày từ nước. Bất ngờ đổ café lên điện thoại, tình cờ gặp mưa, hay đánh rơi máy xuống hồ bơi, … Tất cả đã không còn là mối lo nữa với khả năng chống nước vô cùng bền vững của Realme 5.</p>

<p style="text-align: center;"><img alt="chống nước Realme 5" data-original="https://fptshop.com.vn/Uploads/images/2015/Tin-Tuc/QuanLNH2/realme-5-7.jpg" class="lazydetail" src="..."></p>

<p style="text-align: justify;"><em>Lưu ý: Realme 5 chỉ chống nước cơ bản trong hoạt động thường ngày của bạn, không nên ngâm nước hoặc cố tình mang điện thoại xuống nước.</em></p>

                                </div>
                                <p class="dtcvmodetail"><span>Đọc thêm <i>▾</i></span></p>
                                <p class="dtchide"><span>Rút gọn <i>▴</i></span></p>
                            </div>
                </div>

                        <div data-ss="" class="fs-dtbox" id="thong-so-ky-thuat" style="display:none;">
                            <div class="fs-dttop">
                                <h2>Thông số kỹ thuật của Realme 5 3GB-64GB</h2>
                            </div>

                                <div class="fs-dttskt">

                                    <div style="position: absolute; right: 0; width: 45%;">
                                        <a href="#PopTSKT" title="" data-toggle="modal">
                                            
                                        </a>

                                    </div>

                                    

    <div class="fs-dttskt">

        <div style="position: absolute;right: 0;width: 45%;">
            
        </div>

        <ul class="fs-dttsktul">
            <li class="fs-dttskt-tit">Thông số cơ bản</li>
			
				<li> <label>Màn hình :</label> <span>6.5 inchs, 720 x 1600 Pixels</span> </li>
                            <li> <label>Camera trước :</label> <span>13.0 MP</span> </li>
                            <li> <label>Camera sau :</label> <span>12 MP, 8 MP, 2 MP và 2 MP (4 camera)</span> </li>
							<li> <label>RAM :</label> <span>3 GB</span> </li>
							<li> <label>Bộ nhớ trong :</label> <span>64 GB</span> </li>
                            <li> <label>CPU :</label> <span>Qualcomm Snapdragon 665 AIE, 8, 2.0GHZ</span> </li>
                            <li> <label>GPU :</label> <span>Adreno 610</span> </li>
                            <li> <label>Dung lượng pin :</label> <span>5000mAh</span> </li>
							<li> <label>Hệ điều hành :</label> <span>ColorOS 6.0.1, nền tảng Android 9.0</span> </li>
                                    <li class="fs-dttskt-tit">Camera Trước</li>
                            <li>
                                <label data-id="1334">Thông tin khác :</label>
                                    <span>Đang cập nhật</span>
                            </li>
                            <li>
                                <label data-id="1333">Video Call :</label>
                                    <span>Hỗ trợ VideoCall thông qua ứng dụng</span>
                            </li>
                            <li>
                                <label data-id="1332">Độ phân giải :</label>
                                    <span>13.0 MP</span>
                            </li>
                        <li class="fs-dttskt-tit">Bộ nhớ &amp; Lưu trữ</li>
                            <li>
                                <label data-id="23">Danh bạ lưu trữ :</label>
                                    <span>Tùy bộ nhớ</span>
                            </li>
                            <li>
                                <label data-id="24">ROM :</label>
                                    <span>64 GB</span>
                            </li>
                            <li>
                                <label data-id="1327">Bộ nhớ còn lại :</label>
                                    <span>Đang cập nhật</span>
                            </li>
                            <li>
                                <label data-id="25">Thẻ nhớ ngoài :</label>
                                    <span>MicroSD</span>
                            </li>
                            <li>
                                <label data-id="151">Hỗ trợ thẻ nhớ tối đa :</label>
                                    <span>256 GB</span>
                            </li>
                            <li>
                                <label data-id="226">Kích thước :</label>
                                    <span>Dài 164.4 mm - Ngang 75.6 mm - Dày 9.3 mm()</span>
                            </li>
                        <li class="fs-dttskt-tit">Thiết kế &amp; Trọng lượng</li>
                            <li>
                                <label data-id="212">Trọng lượng  :</label>
                                    <span>198</span>
                            </li>
                            <li>
                                <label data-id="1248">Khả năng chống nước :</label>
                                    <span>Không</span>
                            </li>
                            <li>
                                <label data-id="748">Kiểu dáng :</label>
                                    <span>Nguyên Khối + Thẳng</span>
                            </li>
                            <li>
                                <label data-id="1247">Chất liệu :</label>
                                    <span>Nhựa Polycarbonate</span>
                            </li>
                            <li>
                                <label data-id="749">Kích thước :</label>
                                    <span>164.4 mm x 75.6 mm x 9.3 mm </span>
                            </li>
                        <li class="fs-dttskt-tit">Thông tin pin</li>
                            <li>
                                <label data-id="1250">Chế độ sạc nhanh  :</label>
                                    <span>Có</span>
                            </li>
                            <li>
                                <label data-id="194">Loại pin :</label>
                                    <span>Li-Po</span>
                            </li>
                            <li>
                                <label data-id="36">Dung lượng pin :</label>
                                    <span>5000mAh</span>
                            </li>
                            <li>
                                <label data-id="750">Pin có thể tháo rời :</label>
                                    <span>Không</span>
                            </li>
                            <li>
                                <label data-id="1355">Công nghệ pin :</label>
                                    <span>Tiết kiệm pin</span>
                            </li>
                        <li class="fs-dttskt-tit">Kết nối &amp; Cổng giao tiếp</li>
                            <li>
                                <label data-id="754">GPRS/EDGE :</label>
                                    <span>Có</span>
                            </li>
                            <li>
                                <label data-id="396">NFC :</label>
                                    <span>Không</span>
                            </li>
                            <li>
                                <label data-id="753">Khe cắm sim :</label>
                                    <span>2 ( Sim 2 có thể dùng Sim hoặc thẻ nhớ ngoài)</span>
                            </li>
                            <li>
                                <label data-id="752">Băng tần 4G :</label>
                                    <span>Có</span>
                            </li>
                            <li>
                                <label data-id="156">Loại SIM :</label>
                                    <span>Nano SIM</span>
                            </li>
                            <li>
                                <label data-id="533">Cổng kết nối khác :</label>
                                    <span>	OTG</span>
                            </li>
                            <li>
                                <label data-id="755">Cổng sạc :</label>
                                    <span>MicroUSB</span>
                            </li>
                            <li>
                                <label data-id="35">Jack (Input &amp; Output) :</label>
                                    <span>3.5mm</span>
                            </li>
                            <li>
                                <label data-id="28">Wifi :</label>
                                    <span>802.11 a/b/g/n</span>
                            </li>
                            <li>
                                <label data-id="31">GPS :</label>
                                    <span>A-GPS, GLONASS, BDS</span>
                            </li>
                            <li>
                                <label data-id="30">Bluetooth :</label>
                                    <span>5.0, A2DP, LE</span>
                            </li>
                        <li class="fs-dttskt-tit">Màn hình</li>
                            <li>
                                <label data-id="10">Màu màn hình :</label>
                                    <span>16 Triệu</span>
                            </li>
                            <li>
                                <label data-id="534">Chuẩn màn hình :</label>
                                    <span>HD +</span>
                            </li>
                            <li>
                                <label data-id="204">Công nghệ màn hình :</label>
                                    <span>IPS LCD</span>
                            </li>
                            <li>
                                <label data-id="1160">Màn hình :</label>
                                    <span>6.5 inchs</span>
                            </li>
                            <li>
                                <label data-id="1246">Mặt kính màn hình :</label>
                                    <span>Corning Gorilla Glass 3</span>
                            </li>
                            <li>
                                <label data-id="12">Độ phân giải màn hình :</label>
                                    <span>720 x 1600 Pixels</span>
                            </li>
                        <li class="fs-dttskt-tit">Giải trí &amp; Ứng dụng</li>
                            <li>
                                <label data-id="1251">Đèn pin :</label>
                                    <span>Có</span>
                            </li>
                            <li>
                                <label data-id="193">Chức năng khác :</label>
                                    <span>Đang cập nhật</span>
                            </li>
                            <li>
                                <label data-id="756">Xem phim :</label>
                                    <span>Có</span>
                            </li>
                            <li>
                                <label data-id="757">Nghe nhạc :</label>
                                    <span>Có</span>
                            </li>
                            <li>
                                <label data-id="758">Ghi âm :</label>
                                    <span>Có</span>
                            </li>
                            <li>
                                <label data-id="760">FM radio :</label>
                                    <span>Có</span>
                            </li>
                        <li class="fs-dttskt-tit">Bảo hành</li>
                            <li>
                                <label data-id="46">Thời gian bảo hành :</label>
                                    <span>12 Tháng</span>
                            </li>
                        <li class="fs-dttskt-tit">Hệ điều hành</li>
                            <li>
                                <label data-id="1350">Hệ điều hành :</label>
                                    <span>ColorOS 6.0.1, nền tảng Android 9.0</span>
                            </li>
                        <li class="fs-dttskt-tit">Thông tin dòng sản phẩm</li>
                            <li>
                                <label data-id="1363">Model Series :</label>
                                    <span>Realme 5</span>
                            </li>
                        <li class="fs-dttskt-tit">Camera Sau</li>
                            <li>
                                <label data-id="1328">Độ phân giải :</label>
                                    <span>12 MP, 8 MP, 2 MP và 2 MP (4 camera)</span>
                            </li>
                            <li>
                                <label data-id="1329">Quay phim :</label>
                                    <span>1080p@30fps</span>
                            </li>
                            <li>
                                <label data-id="1330">Đèn Flash :</label>
                                    <span>Có</span>
                            </li>
                            <li>
                                <label data-id="1331">Chụp ảnh nâng cao :</label>
                                    <span>Hỗ trợ Slo-mo 240fps, Chế độ chụp cậnsiêu chụp đêm, tăng cường sắc độ</span>
                            </li>
                        <li class="fs-dttskt-tit">Cấu hình phần cứng</li>
                            <li>
                                <label data-id="649">Tốc độ CPU :</label>
                                    <span>2.0GHZ</span>
                            </li>
                            <li>
                                <label data-id="650">Số nhân :</label>
                                    <span>8</span>
                            </li>
                            <li>
                                <label data-id="651">Chipset :</label>
                                    <span>Qualcomm Snapdragon 665 AIE</span>
                            </li>
                            <li>
                                <label data-id="652">RAM :</label>
                                    <span>3 GB</span>
                            </li>
                            <li>
                                <label data-id="653">Chip đồ họa (GPU) :</label>
                                    <span>Adreno 610</span>
                            </li>
                            <li>
                                <label data-id="1345">Cảm biến :</label>
                                    <span>Đang cập nhật</span>
                            </li>
        </ul>
        <p class="fs-dtcvmo" data-toggle="modal" data-target="#PopTSKTLT"><o class="tstk">Xem chi tiết</o></p>
    </div>


                                </div>
                        </div>
                        <div class="fs-bbotmain" style="display:none;">
                            <div class="fs-bbot clearfix">
                                <div class="fs-bbot1 clearfix">
                                    <p class="fs-bbotimg"><img src="//cdn.fptshop.com.vn/Uploads/Thumbs/2019/9/9/637036416612508502_realme-5-dd.png" alt="Realme 5 3GB-64GB"></p>
                                    <div class="fs-bbotif">
                                        <h3>Realme 5 3GB-64GB</h3>
                                        <p class="fs-bbotpri"><strong>3.990.000₫</strong><del style="display:none;">3.990.000₫</del></p>
                                    </div>
                                </div>
                                <ul class="fs-bbot2 clearfix">
                                    <li><a class="fs-bbotb1" title="Mua trả thẳng" onclick="ga('send', 'event', 'Product Detail', 'Click CTA Button', 'Mua trả thẳng - Below Description');">MUA TRẢ THẲNG</a></li>
                                    <li><a class="fs-bbotb2" title="Mua trả góp 0%" onclick="ga('send', 'event', 'Product Detail', 'Click CTA Button', 'Mua trả góp 0% - Below Description');">MUA TRẢ GÓP 0%</a></li>
                                </ul>
                            </div>
                        </div>
                    <div class="fs-dtbox" id="danh-gia-nhan-xet">
                        <div class="fs-dttop">
                            <h2>Đánh giá &amp; Nhận xét Realme 5 3GB-64GB</h2>
                        </div>
                        <input type="hidden" id="rate-star" value="0">
<div class="fs-dttrating">
    <div class="fs-dtrt-row clearfix">
        <div class="fs-dtrt-col fs-dtrt-c1">
            <h5>3,8/5</h5>
            <ul class="fs-dtrtbig">
                    <li><span class="icdt fs-dtr100"></span></li>
                    <li><span class="icdt fs-dtr100"></span></li>
                    <li><span class="icdt fs-dtr100"></span></li>
                                    <li><span class="icdt fs-dtr50"></span></li>
                                    <li><span class="icdt fs-dtr00"></span></li>
            </ul>
            <p>53 đánh giá &amp; nhận xét</p>
        </div>
        <div class="fs-dtrt-col fs-dtrt-c2"> <ul class="fs-dtrtstar"> <li> <span class="fs-dtrsspan">5 sao</span> <span class="fs-dtrsproc"><span style="width: 37%;"></span></span> <span class="fs-dtrscout">20</span> </li> <li> <span class="fs-dtrsspan">4 sao</span> <span class="fs-dtrsproc"><span style="width: 26%;"></span></span> <span class="fs-dtrscout">14</span> </li> <li> <span class="fs-dtrsspan">3 sao</span> <span class="fs-dtrsproc"><span style="width: 22%;"></span></span> <span class="fs-dtrscout">1</span> </li> <li> <span class="fs-dtrsspan">2 sao</span> <span class="fs-dtrsproc"><span style="width: 1%;"></span></span> <span class="fs-dtrscout">1</span> </li> <li> <span class="fs-dtrsspan">1 sao</span> <span class="fs-dtrsproc"><span style="width: 11%;"></span></span> <span class="fs-dtrscout">6</span> </li> </ul> </div> 
		<div class="fs-dtrt-col fs-dtrt-c3"> <h4>Bạn đã dùng sản phẩm này?</h4> <p class="fs-dtrtbtnnx"><span>Gửi đánh giá của bạn</span></p> </div>
    </div>
    <div class="fs-dtrtcmt">
        <h4 class="fs-dtrtcmti">Gửi nhận xét của bạn</h4>
        <div class="fs-dtrtcmtbox">
            <p class="fs-dtrtcmti2">Bạn chấm sản phẩm này bao nhiêu sao?</p> <div class="fs-dtrtbhov"> <div class="fs-dtrtbig box-star rating"> <input id="radio1" type="radio" name="star" value="5" data-vl="Tuyệt vời" class="star"> <label for="radio1" data-vl="Tuyệt vời" data-star="5"></label> <input id="radio2" type="radio" name="star" value="4" data-vl="Hài lòng" class="star"> <label for="radio2" data-vl="Hài lòng" data-star="4"></label> <input id="radio3" type="radio" name="star" value="3" data-vl="Bình thường" class="star"> <label for="radio3" data-vl="Bình thường" data-star="3"></label> <input id="radio4" type="radio" name="star" value="2" data-vl="Tạm được" class="star"> <label for="radio4" data-vl="Tạm được" data-star="2"></label> <input id="radio5" type="radio" name="star" value="1" data-vl="Không thích" class="star"> <label for="radio5" data-vl="Không thích" data-star="1"></label>  </div> <span class="fs-dtrtbhover"></span> </div>
            <div class="review-error clearfix"><p>Vui lòng chọn đánh giá của bạn về sản phẩm này.</p></div> <textarea id="txtNoteRating" name="txtNoteRating" rows="3" class="f-cmttarea fsformsc" placeholder="Bạn có khuyên người khác mua sản phẩm này không? Tại sao?"></textarea> <p class="noti" style="color:#d0011b;font-size: 12px;display:none">Mời bạn đánh giá sản phẩm.(Tối thiểu 3 ký tự)</p> <div class="fs-dtrtbots clearfix">  <p>Một đánh giá có ích thường dài từ 100 ký tự trở lên</p> <ul> <li><button type="button" class="fs-dtrtbot-huy" href="" title="">Hủy</button> </li> <li><button type="button" class="fs-dtrtbots-gui btn-gui-rate">Gửi</button> </li> </ul> </div>
        </div>
    </div>
    <div class="fs-dttratetit clearfix">
        <h4>Khách hàng nhận xét (<strong class="totalrates">2</strong>)</h4>
        <ul>
            <li class="rate-sort active" data-id="1"><a href="javascript:void(0);" title="">Mới nhất</a></li>
            <li class="rate-sort" data-id="0"><a href="javascript:void(0);" title="">Hữu ích nhất</a></li>
        </ul>
    </div>
    <div class="fs-dttranull">
        <p>Chưa có nhận xét nào.</p>
        <p>Hãy là người nhận xét đầu tiên</p>
        <p><button class="fs-dttranobtn" type="button">Viết nhận xét</button></p>
    </div>
    <div class="fs-dttratemain" id="listRate">
        <div class="fs-dttrateitem rate-review-top"></div>
    
    <div class="fs-dttrateitem">
        <div class="fs-dttrate">
            <ul>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                                            </ul>

        </div>
        <div class="fs-dttrcre">
            <ul class="fs-rtlul">
                <li>Bởi: <strong>Đông Phương Hạ Băng</strong></li>
                <li>

                </li>
                <li>
                        <span>10 ngày trước</span>
                </li>
            </ul>
        </div>

        <div class="fs-dttrtxt">
            Máy đẹp phết
        </div>
            <p class="fs-dttrlike rate-like" data-id="110503"><span><i class="icdt irtlike"></i>5</span></p>


    </div>
    <div class="fs-dttrateitem">
        <div class="fs-dttrate">
            <ul>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                    <li>
                        <span class="fs-dttr10"></span>
                    </li>
                                            </ul>

        </div>
        <div class="fs-dttrcre">
            <ul class="fs-rtlul">
                <li>Bởi: <strong>Anh Đạt</strong></li>
                <li>

                </li>
                <li>
                        <span>vào ngày 20/09/2019</span>
                </li>
            </ul>
        </div>

        <div class="fs-dttrtxt">
            với tầm khúc trung mà ram và rom cấu hình này thì ngon nghẻ rồi realme đợt này tạo sự bứt phả ra phết
        </div>
            <p class="fs-dttrlike rate-like" data-id="109439"><span><i class="icdt irtlike"></i>19</span></p>


    </div>

</div>
    <p class="fs-dttrvmo list-rate-more" data-page="2" style="display: none;"><span>Xem tất cả <strong id="totalrateres">-2</strong> nhận xét</span></p>
</div>


                    </div>
                    <input type="hidden" id="brand-id" data-id="212">
                    <input type="hidden" id="type-product" data-id="1">
                    <div class="fs-comment" id="hoi-dap">
                        <div class="fs-cmttit">
                            Hỏi Đáp về Realme 5 3GB-64GB
                        </div>
                        
<div class="fs-cmtmain">

    <div class="fs-cmttop clearfix">
        <textarea rows="3" class="f-cmttarea txa-cmt" id="txa-cmt" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
        <p class="noticmt">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
        <div id="uploads" class="uploads"></div>
        <ul class="fs-cmbtns">
            
            <li><button class="fs-cmbtn-send" id="btn-cmt-gui" type="button">Gửi câu hỏi</button></li>
        </ul>
    </div>
    <div class="f-cmtarbot" id="list-comment-top">

        <!--cmt-->
    </div>
    <div class="f-cmtarbot" id="list-comment">


        <input id="info-comment" type="hidden" value="">
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="vinh" style="width: 30px; height: 30px;"><abbr title="vinh">V</abbr></div>
                </div>

            <strong class="f-cmname">vinh</strong>
            <span class="f-cmtime">2 giờ trước</span>
            <div class="f-cmmain">còn này có những mầu gì thế shop</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3931057 f-cmpost" data-id="3931057">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3931057">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Nguyễn Hồng Quân</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">2 giờ trước</span>
                        <div class="f-cmmain"><p>Chào Vinh,<br>
Dạ bên mình có màu Xanh và màu Tím bạn nhé.&nbsp;Mời bạn liên hệ tổng đài miễn phí 18006601 hoặc để lại số điện thoại tại đây, các nhân viên sẽ hỗ trợ bạn đặt hàng ạ.<br>
Thân mến !</p>

<p>&nbsp;</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3931057 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3931057" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3931057">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Nguyễn Văn đỉnh " style="width: 30px; height: 30px;"><abbr title="Nguyễn Văn đỉnh">NV</abbr></div>
                </div>

            <strong class="f-cmname">Nguyễn Văn đỉnh </strong>
            <span class="f-cmtime">19 giờ trước</span>
            <div class="f-cmmain">Có van tay ko shop</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3930086 f-cmpost" data-id="3930086">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3930086">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Nguyễn Thiện Nhật Quyền</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">19 giờ trước</span>
                        <div class="f-cmmain"><p>Chào Đỉnh,<br>
Dạ&nbsp; máy có bảo mật vân tay ở mặt lưng bạn nha. Thân mến!</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3930086 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3930086" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3930086">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Nguyễn Hiền" style="width: 30px; height: 30px;"><abbr title="Nguyễn Hiền">NH</abbr></div>
                </div>

            <strong class="f-cmname">Nguyễn Hiền</strong>
            <span class="f-cmtime">1 ngày trước</span>
            <div class="f-cmmain">Mã giảm giá có áp dụng mua trực tiếp và đồng thời với thanh toán qua vn pay ko ạ</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3929715 f-cmpost" data-id="3929715">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3929715">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Nguyễn Thị Tùng Vy</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">1 ngày trước</span>
                        <div class="f-cmmain"><p>Chào Hiền,<br>
Dạ mã giảm giá áp dụng đặt mua máy Online bạn nha và được áp dụng cùng giảm đến 200.000 đồng khi thanh toán qua VNPAY-QR tại FPT Shop ạ.&nbsp;Bạn quan tâm có thể đặt hàng để sở hữu ngay sản phẩm ngay bây giờ bạn nhé. Để đặt hàng bạn có thể để lại SĐT bên mình sẽ hỗ trợ bạn nhanh nhất bạn nhé.<br>
Cảm ơn bạn đã quan tâm đến sản phẩm!</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3929715 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3929715" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3929715">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Tuấn Anh" style="width: 30px; height: 30px;"><abbr title="Tuấn Anh">TA</abbr></div>
                </div>

            <strong class="f-cmname">Tuấn Anh</strong>
            <span class="f-cmtime">1 ngày trước</span>
            <div class="f-cmmain">Máy sạc lúc vô pin lúc k vô phải cấm lại trên dưới 5 lần</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3929330 f-cmpost" data-id="3929330">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3929330">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Nguyễn Thị Tùng Vy</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">1 ngày trước</span>
                        <div class="f-cmmain"><p>Chào Tuấn Anh,<br>
Dạ với trường hợp này,&nbsp; nếu sản phẩm của bạn được mua tại FPT Shop, bạn vui lòng dành chút thời gian mang&nbsp; đến Shop, kỹ thuật viên bên mình sẽ kiểm tra và có phương án phù hợp hỗ trợ bạn nhanh nhất bạn nha.<br>
Mình xin thông tin đến bạn!</p>

<p>&nbsp;</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3929330 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3929330" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3929330">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Hà Trang" style="width: 30px; height: 30px;"><abbr title="Hà Trang">HT</abbr></div>
                </div>

            <strong class="f-cmname">Hà Trang</strong>
            <span class="f-cmtime">1 ngày trước</span>
            <div class="f-cmmain">Trả góp 30% thì một tháng mình phải trả bao nhiêu nữa ạ</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3928922 f-cmpost" data-id="3928922">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3928922">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Linh Văn Hiếu</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">1 ngày trước</span>
                        <div class="f-cmmain"><p>Chào Hà Trang,<br>
Bạn trả góp trả trước 30% kỳ hạn 4 tháng với mỗi tháng&nbsp;737.000đ bạn nha.&nbsp;Để được tư vấn chi tiết bạn vui lòng để lại SĐT hoặc liên hệ tổng đài miễn phí 18006601, bên mình sẽ hỗ trợ bạn nhanh nhất ạ.<br>
Thân mến!</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3928922 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3928922" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3928922">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Minh Nhật" style="width: 30px; height: 30px;"><abbr title="Minh Nhật">MN</abbr></div>
                </div>

            <strong class="f-cmname">Minh Nhật</strong>
            <span class="f-cmtime">2 ngày trước</span>
            <div class="f-cmmain">E sn 12-2000 trả góp đc ko ạ 
Và trả trước bao  nhiêu%
</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3927780 f-cmpost" data-id="3927780">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3927780">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Nguyễn Thị Tùng Vy</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">2 ngày trước</span>
                        <div class="f-cmmain"><p>Chào Nhật,<br>
Dạ với trả góp 0% bạn trả trước&nbsp;1.197.000₫ (30%) ạ. Bạn đã đủ 18 tuổi trở lên có thể tham gia trả góp bạn nha.Tuy nhiên kết quả xét duyệt hồ sơ do nhà tài chính quyết định, bạn có thể đăng kí hồ sơ trả góp Online và khi có kết quả bạn vui lòng đến Shop để hoàn tất thủ tục ạ.<br>
Mình xin thông tin đến bạn!</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3927780 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3927780" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3927780">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Vinh" style="width: 30px; height: 30px;"><abbr title="Vinh">V</abbr></div>
                </div>

            <strong class="f-cmname">Vinh</strong>
            <span class="f-cmtime">2 ngày trước</span>
            <div class="f-cmmain">Kiểm tra dung lượng thẻ nhớ ở trên điện thoại ở mục nào</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3927382 f-cmpost" data-id="3927382">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3927382">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Nguyễn Thiện Nhật Quyền</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">2 ngày trước</span>
                        <div class="f-cmmain"><p>Chào Vinh,<br>
Dạ bạn có thể vào cài đặt&gt; bộ nhớ để kiểm tra dung lượng ạ. Thân mến!</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3927382 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3927382" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3927382">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Vinh" style="width: 30px; height: 30px;"><abbr title="Vinh">V</abbr></div>
                </div>

            <strong class="f-cmname">Vinh</strong>
            <span class="f-cmtime">2 ngày trước</span>
            <div class="f-cmmain">Realme 5 muốn kiểm tra và xem thẻ nhớ ở chỗ nào vậy</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3927352 f-cmpost" data-id="3927352">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3927352">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Nguyễn Thiện Nhật Quyền</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">2 ngày trước</span>
                        <div class="f-cmmain"><p>Chào Vinh,<br>
Dạ thẻ nhớ của máy nằm cùng với khe sim ạ, bạn có thể lấy khay sim ra nha. Thân mến!</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3927352 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3927352" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3927352">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Tiến" style="width: 30px; height: 30px;"><abbr title="Tiến">T</abbr></div>
                </div>

            <strong class="f-cmname">Tiến</strong>
            <span class="f-cmtime">2 ngày trước</span>
            <div class="f-cmmain">Sạc đi kèm máy là bao nhiêu W ???</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3927308 f-cmpost" data-id="3927308">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3927308">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Nguyễn Thiện Nhật Quyền</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">2 ngày trước</span>
                        <div class="f-cmmain"><p>Chào Tiến,<br>
Dạ củ sạc kèm máy là 10W bạn nha. Thân mến!</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3927308 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3927308" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3927308">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->
        <div class="f-cmt-ask">
                <div class="f-cmuser">
                    <div class="textavatar fhdcmtava" data-name="Lan Phuong" style="width: 30px; height: 30px;"><abbr title="Lan Phuong">LP</abbr></div>
                </div>

            <strong class="f-cmname">Lan Phuong</strong>
            <span class="f-cmtime">2 ngày trước</span>
            <div class="f-cmmain">Cho mình hỏi: mình mua realme 5 màu xanh. Vì tin Nv bán hàng cho nên ko kiểm tra kĩ. Nên đã nhầm hàng là màu tím. Vậy bây giờ làm sao ak</div>
            <p class="f-cmbott"> <span class="answer-comment answer-comment-3927130 f-cmpost" data-id="3927130">Trả lời</span> </p>
        </div>
        <div class="f-cmt-reply rep-3927130">

                    <div class="f-cmt-ask">

                        <span class="f-cmuser f-cmqtv"></span>
                        <strong class="f-cmname">Linh Văn Hiếu</strong>
                        <strong class="f-cmadm">QTV</strong>
                        <span class="f-cmtime">2 ngày trước</span>
                        <div class="f-cmmain"><p>Chào Lan,<br>
Trường hợp trên,&nbsp;bạn vui lòng để lại thông tin liên hệ (Tên, số điện thoại), bên mình sẽ chủ động liên hệ hỗ trợ cho bạn ạ.<br>
Mong nhận được phản hồi từ bạn!</p>
</div>
                    </div>
                        <!--1-->
			
			
        </div>
        <div class="f-cmttop answer-comment-3927130 box-comment-sub clearfix" style="display: none;">
            <textarea rows="3" class="f-cmttarea form-control txa_comment_3927130" placeholder="Viết bình luận của bạn (Vui lòng gõ tiếng Việt có dấu)"></textarea>
            <p class="noticmtsub" style="color:red;display:none">Mời bạn viết bình luận.(Tối thiểu 3 ký tự)</p>
            <ul class="fs-cmbtns">
                
                <li><button class="fs-cmbtn-send btn_comment_send_sub" type="button" data-id="3927130">Gửi câu hỏi</button></li>
            </ul>
        </div>
        <!--cmt-->

        <!--cmt-->
    </div>
        <div data-link="http://fptshop.com.vn/dien-thoai/realme-5" data-pagesize="10" data-total="401" data-step="3" class="detail-newsmo-mores f-cmtpaging">

            <div class="clearfix">
                <ul class="clearfix"><li class="active"><a class="pageNumber" data-page="1" href="javascript:;">1</a></li><li><a class="pageNumber" data-page="2" href="javascript:;">2</a></li><li><a class="pageNumber" data-page="3" href="javascript:;">3</a></li><li><a class="pageNumber" data-page="4" href="javascript:;">4</a></li><li><a href="javascript:;">...</a></li><li><a class="pageNumber" data-page="2" href="javascript:;">»</a></li><li><a class="pageNumber" data-page="41" href="javascript:;">»»</a></li></ul>
            </div>
        </div>
		<input type="hidden" id="hdTQues" value="401">
</div>

                    </div>
                        <div class="fs-dtbox" id="hinh-anh">
                            <div class="fs-dttop">
                                <h2>Hình ảnh thực tế (14 ảnh)</h2>
                            </div>
                            <div class="fs-imggalary">
                                <div class="fs-icate clearfix">
                                    <div class="owl-carousel fsicte otherlazy owl-loaded owl-drag" data-items="6">
                                            
                                            
                                            
                                            
                                            
                                            
                                            
                                            
                                            
                                            
                                            
                                            
                                            
                                            
                                    <div class="owl-stage-outer"><div class="owl-stage" style="transform: translate3d(0px, 0px, 0px); transition: all 0s ease 0s; width: 1662px;"><div class="owl-item active" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988520328620_realme5-13.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988520328620_realme5-13.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item active" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988530905626_realme5-11.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988530905626_realme5-11.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item active" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988488666592_realme5-2.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988488666592_realme5-2.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item active" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988457022904_realme5-42.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988457022904_realme5-42.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item active" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988452186183_realme5-4.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988452186183_realme5-4.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item active" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988421551907_realme5-14.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988421551907_realme5-14.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988434266787_realme5-8.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988434266787_realme5-8.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988433510332_realme5-41.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988433510332_realme5-41.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988352577699_realme5-10.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988352577699_realme5-10.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988352103632_realme5-44.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988352103632_realme5-44.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988349232294_realme5-7.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988349232294_realme5-7.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988348526188_realme5-43.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988348526188_realme5-43.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988352890104_realme5-5.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988352890104_realme5-5.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div><div class="owl-item" style="width: 118.667px;"><div class="item">
                                                <a class="fancybox-thumb" rel="fancybox-thumb" href="//cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988349052121_realme5-1.JPG" title="">
                                                    <p class="fs-imgls">
                                                        <img class="owl-lazy" data-src="https://images.fpt.shop/unsafe/fit-in/118x79/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/17/637068988349052121_realme5-1.JPG" alt="">
                                                    </p>
                                                </a>
                                            </div></div></div></div><div class="owl-nav"><div class="owl-prev disabled"></div><div class="owl-next"></div></div><div class="owl-dots disabled"></div></div>
                                </div>
                            </div>
                        </div>
            </div>
                <div class="fs-dtcol2">
                        <style>.fs-tsright{padding:15px;background:#fff;margin-bottom:20px}.fs-tsright ul li{display:table;width:100%;padding:5px 0}.fs-tsright ul li label,.fs-tsright ul li span{display:table-cell;vertical-align:top}.fs-tsright ul li label{width:100px;font-size:13px;color:#616161;padding-right:6px}.fs-tsright ul li span{color:#3d3d3d;font-size:13px}.fs-tsright ul li a{color:#337ab7}.fs-tsrvmo{text-align:center;padding:10px 0 0}.fs-tsrvmo span{cursor:pointer;display:block;height:36px;line-height:36px;text-align:center;font-size:13px;color:#337ab7;border-radius:2px;background-color:#fff;border:solid 1px #337ab7}</style>
                        <div class="fs-dtbox main_spec">
                            <div class="fs-dttop">
                                <h2>Thông số kỹ thuật</h2>
                            </div>
                            <div class="fs-tsright">

        <ul>
				<li> <label>Màn hình :</label> <span>6.5 inchs, 720 x 1600 Pixels</span> </li>
                            <li> <label>Camera trước :</label> <span>13.0 MP</span> </li>
                            <li> <label>Camera sau :</label> <span>12 MP, 8 MP, 2 MP và 2 MP (4 camera)</span> </li>
							<li> <label>RAM :</label> <span>3 GB</span> </li>
							<li> <label>Bộ nhớ trong :</label> <span>64 GB</span> </li>
                            <li> <label>CPU :</label> <span>Qualcomm Snapdragon 665 AIE, 8, 2.0GHZ</span> </li>
                            <li> <label>GPU :</label> <span>Adreno 610</span> </li>
                            <li> <label>Dung lượng pin :</label> <span>5000mAh</span> </li>
							<li> <label>Hệ điều hành :</label> <span>ColorOS 6.0.1, nền tảng Android 9.0</span> </li>
			                <li> <label>Thẻ SIM :</label> <span>2 ( Sim 2 có thể dùng Sim hoặc thẻ nhớ ngoài), Nano SIM, hỗ trợ 4G</span> </li>
								                </ul>
    <style>.fs-ifsimss{position:relative;padding-left:44px;font-size:13px;color:#4a4a4a}.fs-ifsimss span{position:absolute;left:0;top:0;padding:0 5px;display:inline-block;height:18px;line-height:18px;border-radius:8px;color:#fff;font-size:12px;font-weight:bold;background-color:#e40000}.fs-ifsimss a{color:#337ab7}.fs-ifsimss strong{color:#d0021b}</style>
    <p class="fs-ifsimss"><span>HOT</span> <a href="/sim-so-dep/chon-so/viettel/00529745" title="Sim Alo Max90 Viettel" target="_blank">Sim Alo Max90 Viettel</a> (5GB data/ tháng, miễn phí gọi nội mạng &lt;10 phút, miễn phí 15 phút ngoại mạng). Giá từ <strong>80.000đ</strong></p>
    <p class="fs-tsrvmo" data-toggle="modal" data-target="#PopTSKTLT"><span class="tstk" onclick="ga('send', 'event', 'Product Detail', 'Click chi tiết cấu hình', 'Xem cấu hình chi tiết');">Xem cấu hình chi tiết</span></p>
                            </div>
                        </div>
                    

                    <div class="fs-dtbox" id="tin-tuc">
                        <div class="fs-dttop">
                            <h2>Bài viết về Realme 5 3GB-64GB</h2>
                        </div>
                        <input type="hidden" id="totalnews" value="4">
    <div class="fs-dtrbv">
        <ul>
                <li class="clearfix"> <a class="fs-dtrbvimg" href="/tin-tuc/danh-gia/duoi-4-trieu-co-the-chon-duoc-smartphone-choi-game-tot-khong-104127" title=""> 
				<img class="lazy" src="https://images.fpt.shop/unsafe/fit-in/90x90/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/28/637078605738942793_cover.jpg" data-original="https://images.fpt.shop/unsafe/fit-in/90x90/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/28/637078605738942793_cover.jpg" alt="Dưới 4 triệu có thể chọn được smartphone chơi game tốt không?" style="display: block;"> <h3>Dưới 4 triệu có thể chọn được smartphone chơi game tốt không?</h3></a>
				</li>
                <li class="clearfix"> <a class="fs-dtrbvimg" href="/tin-tuc/tin-moi/realme-hien-da-co-da-co-hon-17-trieu-nguoi-dung-103427" title=""> 
				<img class="lazy" src="https://images.fpt.shop/unsafe/fit-in/90x90/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/15/637067699565037573_realme-3.jpg" data-original="https://images.fpt.shop/unsafe/fit-in/90x90/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/15/637067699565037573_realme-3.jpg" alt="Realme hiện đã có đã có hơn 17 triệu người dùng" style="display: block;"> <h3>Realme hiện đã có đã có hơn 17 triệu người dùng</h3></a>
				</li>
                <li class="clearfix"> <a class="fs-dtrbvimg" href="/tin-tuc/danh-gia/tong-hop-nhung-smartphone-duoi-4-trieu-co-hieu-nang-xin-va-vien-pin-trau-103021" title=""> 
				<img class="lazy" src="https://images.fpt.shop/unsafe/fit-in/90x90/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/8/637061406848090185_realme-5-1.jpg" data-original="https://images.fpt.shop/unsafe/fit-in/90x90/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/8/637061406848090185_realme-5-1.jpg" alt="Tổng hợp những smartphone dưới 4 triệu có hiệu năng “xịn” và viên pin &quot;trâu&quot;" style="display: block;"> <h3>Tổng hợp những smartphone dưới 4 triệu có hiệu năng “xịn” và viên pin "trâu"</h3></a>
				</li>
                <li class="clearfix"> <a class="fs-dtrbvimg" href="/tin-tuc/danh-gia/khoang-6-trieu-realme-5-pro-se-dem-den-nhung-trai-nghiem-nao-103003" title=""> 
				<img class="lazy" src="https://images.fpt.shop/unsafe/fit-in/90x90/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/7/637060413215001095_realme-5-pro.jpg" data-original="https://images.fpt.shop/unsafe/fit-in/90x90/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/10/7/637060413215001095_realme-5-pro.jpg" alt="Khoảng 6 triệu, Realme 5 Pro sẽ đem đến những trải nghiệm nào?" style="display: block;"> <h3>Khoảng 6 triệu, Realme 5 Pro sẽ đem đến những trải nghiệm nào?</h3></a>
				</li>
        </ul>
            <p class="fs-dtrvm">
				
				<a href="http://fptshop.com.vn/tin-tuc/san-pham/realme-5-28927" target="_blank"> Xem tất cả </a>
			</p>
    </div>

                    </div>
                        <div class="fs-dtbox">
                            <div class="fs-dttop">
                                <h2>So sánh sản phẩm tương đương</h2>
                            </div>

                            <div class="fs-dtrpk fs-dtrpk2">
                                <ul>
                                    <li class="clearfix">
                                        <a class="fs-dtrpkimg" href="/dien-thoai/realme-5" target="_blank" title="">
											<img src="..." data-original="https://images.fpt.shop/unsafe/fit-in/80x80/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/9/9/637036416612508502_realme-5-dd.png" alt="Realme 5 3GB-64GB" class="lazy">
                                        </a>
                                        <div class="fs-dtrpkif">
                                            <a href="/dien-thoai/realme-5" target="_blank" title="">
                                                <h3><strong>Realme 5 3GB-64GB</strong></h3>
                                            </a>
                                                <p>3.990.000 ₫</p>
                                            <ul class="fs-dtrss"><li><label>Màn hình :</label>720 x 1600 Pixels 6.5 inchs</li><li><label>Camera :</label>12 MP, 8 MP, 2 MP và 2 MP (4 camera) 13.0 MP</li><li><label>Pin :</label>5000mAh</li><li><label>RAM :</label>3 GB</li><li><label>CPU :</label>Qualcomm Snapdragon 665 AIE</li><li><label>HĐH:</label>ColorOS 6.0.1, nền tảng Android 9.0</li></ul>
                                            <strong class="fs-dtrpkif-on">Sản phẩm đang xem</strong>
                                        </div>
                                    </li>
                                        <li class="clearfix">
                                            <a class="fs-dtrpkimg" href="/dien-thoai/vivo-v11i" title="Vivo V11i">
												<img class="lazy" src="..." data-original="https://images.fpt.shop/unsafe/fit-in/80x80/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2018/12/25/636813421407138329_vivo-v11i-daidien.png" alt="Vivo V11i">
                                            </a>
                                            <div class="fs-dtrpkif">
                                                <a href="/dien-thoai/vivo-v11i" title="">
                                                    <h3><strong>Vivo V11i</strong></h3>
                                                </a>
											
                                                <p>3.990.000 ₫</p>
                                                <ul class="fs-dtrss"><li><label>Màn hình :</label>1080 x 2280 Pixels 6.3 inchs</li><li><label>Camera :</label>16.0 + 5.0 MP(Dual Camera) 25.0 MP</li><li><label>Pin :</label>3315mAh</li><li><label>RAM :</label>4 GB</li><li><label>CPU :</label>Helio P60 -Octa-core 2.0GHz</li><li><label>HĐH:</label>Android 8</li></ul>

                                                <a href="/so-sanh-san-pham?realme-5-vs-vivo-v11i" class="fs-dtrpkif-ss" target="_blank" title="" onclick="ga('send', 'event', 'Product Detail', 'Click CTA Button', 'So sánh chi tiết');">Xem so sánh chi tiết</a>
                                            </div>
                                        </li>
                                        <li class="clearfix">
                                            <a class="fs-dtrpkimg" href="/dien-thoai/samsung-galaxy-m20" title="Samsung Galaxy M20">
												<img class="lazy" src="..." data-original="https://images.fpt.shop/unsafe/fit-in/80x80/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/2/13/636856463604969792_Galaxy-M20.png" alt="Samsung Galaxy M20">
                                            </a>
                                            <div class="fs-dtrpkif">
                                                <a href="/dien-thoai/samsung-galaxy-m20" title="">
                                                    <h3><strong>Samsung Galaxy M20</strong></h3>
                                                </a>
											
                                                <p>3.990.000 ₫</p>
                                                <ul class="fs-dtrss"><li><label>Màn hình :</label>1080 x 2340 Pixels 6.3 inches</li><li><label>Camera :</label>13.0 MP + 5.0 MP 8.0 MP</li><li><label>Pin :</label>5000 mAh</li><li><label>RAM :</label>3 GB</li><li><label>CPU :</label>Exynos 7904 8 nhân 64-bit</li><li><label>HĐH:</label>Android 8 (Oreo)</li></ul>

                                                <a href="/so-sanh-san-pham?realme-5-vs-samsung-galaxy-m20" class="fs-dtrpkif-ss" target="_blank" title="" onclick="ga('send', 'event', 'Product Detail', 'Click CTA Button', 'So sánh chi tiết');">Xem so sánh chi tiết</a>
                                            </div>
                                        </li>
                                        <li class="clearfix">
                                            <a class="fs-dtrpkimg" href="/dien-thoai/honor-10-lite-64gb" title="Honor 10 Lite 64GB">
												<img class="lazy" src="..." data-original="https://images.fpt.shop/unsafe/fit-in/80x80/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/1/17/636833151047947567_honor-10-lite-64gb-daidien.png" alt="Honor 10 Lite 64GB">
                                            </a>
                                            <div class="fs-dtrpkif">
                                                <a href="/dien-thoai/honor-10-lite-64gb" title="">
                                                    <h3><strong>Honor 10 Lite 64GB</strong></h3>
                                                </a>
											
                                                <p>3.990.000 ₫</p>
                                                <ul class="fs-dtrss"><li><label>Màn hình :</label>1080 x 2340 Pixels 6.21 inches</li><li><label>Camera :</label>13.0 MP + 2.0 MP 24.0 MP</li><li><label>Pin :</label>3400 mAh</li><li><label>RAM :</label>3 GB</li><li><label>CPU :</label>Hisilicon Kirin 710</li><li><label>HĐH:</label>Android 9</li></ul>

                                                <a href="/so-sanh-san-pham?realme-5-vs-honor-10-lite-64gb" class="fs-dtrpkif-ss" target="_blank" title="" onclick="ga('send', 'event', 'Product Detail', 'Click CTA Button', 'So sánh chi tiết');">Xem so sánh chi tiết</a>
                                            </div>
                                        </li>
                                        <li class="clearfix">
                                            <a class="fs-dtrpkimg" href="/dien-thoai/vivo-y12-3gb-64gb" title="Vivo Y12 3GB-64GB">
												<img class="lazy" src="..." data-original="https://images.fpt.shop/unsafe/fit-in/80x80/filters:quality(90):fill(white)/cdn.fptshop.com.vn/Uploads/Originals/2019/7/16/636988886949471741_vivo-y12-dd.png" alt="Vivo Y12 3GB-64GB">
                                            </a>
                                            <div class="fs-dtrpkif">
                                                <a href="/dien-thoai/vivo-y12-3gb-64gb" title="">
                                                    <h3><strong>Vivo Y12 3GB-64GB</strong></h3>
                                                </a>
											
                                                <p>3.990.000 ₫</p>
                                                <ul class="fs-dtrss"><li><label>Màn hình :</label>1544 x 720 Pixels 6.35 inchs</li><li><label>Camera :</label>13 Mp + 8 MP + 2 MP 8.0 MP</li><li><label>Pin :</label>5000mAh</li><li><label>RAM :</label>3 GB</li><li><label>CPU :</label>Helio P22</li><li><label>HĐH:</label>Android 9</li></ul>

                                                <a href="/so-sanh-san-pham?realme-5-vs-vivo-y12-3gb-64gb" class="fs-dtrpkif-ss" target="_blank" title="" onclick="ga('send', 'event', 'Product Detail', 'Click CTA Button', 'So sánh chi tiết');">Xem so sánh chi tiết</a>
                                            </div>
                                        </li>
                                </ul>
                                
                            </div>

                        </div>
                </div>
            
        </div>"""

# %%
response = Selector(text=text)

# %%
response.css('div.fs-tsright li')
# Out:
# [<Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' fs-tsright ')]/descendant-or-self::*/li" data='<li> <label>Màn hình :</label> <span>...'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' fs-tsright ')]/descendant-or-self::*/li" data='<li> <label>Camera trước :</label> <s...'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' fs-tsright ')]/descendant-or-self::*/li" data='<li> <label>Camera sau :</label> <spa...'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' fs-tsright ')]/descendant-or-self::*/li" data='<li> <label>RAM :</label> <span>3 GB<...'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' fs-tsright ')]/descendant-or-self::*/li" data='<li> <label>Bộ nhớ trong :</label> <s...'>,
# ...

# %%
for item in response.css('div.fs-tsright li'):
    if (item.css('label::text').extract_first() == 'Màn hình :'):
        article['screen'] = item.css('span::text').extract_first()

# %%
article
# Out:
# {'screen': '6.5 inchs, 720 x 1600 Pixels'}

# %%
for item in response.css('div.fs-tsright li'):
    if (item.css('label::text').extract_first() == 'Màn hình :'):
        article['screen'] = item.css('span::text').extract_first()
    if(item.css('label::text').extract_first() == 'RAM :'):
        article['ram'] = item.css('span::text').extract_first()
article
# Out:
# {'screen': '6.5 inchs, 720 x 1600 Pixels', 'ram': '3 GB'}
